# %% [markdown]
# <a href="https://colab.research.google.com/github/jackcurse/-bmchl-c/blob/main/BST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BST():
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
  
  def insert(self, data):
    if self.data is None:
      self.data = data
      return
    if self.data == data:
      return
    if self.data > data:
      if self.left:
        return self.left.insert(data)
      else:
        self.left = BST(data)    
    else:
      if self.right:
        return self.right.insert(data)
      else:
        self.right = BST(data)

    def search(self, data):
      if self.data == data:
        print("")    

root = BST(None)
y = [10, 9, 1, 2, 6, 3, 5]
for i in y:
  root.insert(i)
